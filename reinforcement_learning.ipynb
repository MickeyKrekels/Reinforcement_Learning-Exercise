# %% [markdown]
# # Reinforcement Learning exercise with Q-learning
# by Mickey Krekels
#
# The goal of this project is to learn how to implement Q-learning in combination with the game/simulation library Gym form OpenAI.
#
# ## Dowloading Libaries

# %%
# !pip install tensorflow
# !pip install gym
# !pip install keras
# !pip install keras-rl2
# Out:
# Requirement already satisfied: tensorflow in c:\users\micke\appdata\roaming\python\python39\site-packages (2.6.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: keras~=2.6 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: absl-py~=0.10 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (0.14.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: clang~=5.0 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (5.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: six~=1.15.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.40.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: gast==0.4.0 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (58.1.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.26.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.2.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=0.11.15->tensorboard~=2.6->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Requirement already satisfied: gym in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (0.26.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from gym) (2.2.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from gym) (4.12.0)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from gym) (0.0.8)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from gym) (1.19.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.8.0->gym) (3.8.1)
# Requirement already satisfied: keras in c:\users\micke\appdata\roaming\python\python39\site-packages (2.6.0)
# Requirement already satisfied: keras-rl2 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (1.0.5)
# Requirement already satisfied: tensorflow in c:\users\micke\appdata\roaming\python\python39\site-packages (from keras-rl2) (2.6.0)
# Requirement already satisfied: keras~=2.6 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (2.6.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (1.15.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (3.3.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (0.37.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (1.1.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (0.4.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (3.7.4.3)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (2.6.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (3.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (3.17.3)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: clang~=5.0 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (5.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (1.40.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (1.12)
# Requirement already satisfied: tensorflow-estimator~=2.6 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (2.6.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->keras-rl2) (1.19.5)
# Requirement already satisfied: absl-py~=0.10 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (0.14.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorflow->keras-rl2) (1.12.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.26.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (58.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\micke\appdata\roaming\python\python39\site-packages (from tensorboard~=2.6->tensorflow->keras-rl2) (3.3.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->keras-rl2) (1.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (2.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow->keras-rl2) (1.26.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=0.11.15->tensorboard~=2.6->tensorflow->keras-rl2) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow->keras-rl2) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\micke\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow->keras-rl2) (3.1.1)

# %% [markdown]
# ## Loading imports

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

import random
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

from collections import deque
from keras.models import Sequential
from keras.layers import InputLayer
from keras.layers import Dense

from os import system

# %% [markdown]
# # The Taxi game
#
# For this exercise, the game Taxi-v3 is going to be used from the gym library. <br>
#
# The goal of the game is to pick up passengers as the taxi player and bring them to the desired destination in the least amount of moves. <br>
#
# There are **6 actions** used in the game these include:
# - [0] : go south
# - [1] : go north
# - [2] : go east
# - [3] : go west
# - [4] : pick up passenger
# - [5] : drop off passenger

# %% [markdown]
# ## Creating an costum environment

# %%
game_name = 'Taxi-v3'
env = gym.make(game_name)
action_space = env.action_space 
action_space.n
# Out:
# 6

# %%
env = gym.make(game_name)
print(f'number of observation spaces: {env.observation_space}')
print(f'number of action spaces: {env.action_space.n}')
# Out:
# number of observation spaces: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# number of action spaces: 3

# %% [markdown]
# Testing the game environment

# %%
env = gym.make(game_name, render_mode='human') #<----- for rendering the environment

observation, _ = env.reset()
max_steps =20
for i in range(max_steps):
    action = env.action_space.sample()
    try:
        observation, reward, terminated, truncated, _ = env.step(action)
    except OverflowError:
        break
    
    if truncated:
        observation, _ = env.reset()

env.close()

# %% [markdown]
# Initial state of the environment when the reset method is called

# %%
env = gym.make(game_name)
print(env.reset())
env.close()
# Out:
# (array([-0.533374,  0.      ], dtype=float32), {})

# %% [markdown]
# The state of the environment when the step method is called (for example, a = 1).

# %%
env = gym.make(game_name)
env.reset()
print(env.step(1))
env.close()
# Out:
# (array([-5.8181584e-01,  4.3764384e-04], dtype=float32), -1.0, False, False, {})

# %% [markdown]
# Looking at the lenght of the options aviable

# %%
env = gym.make(game_name)
nb_actions = env.action_space.n
env.close()
nb_actions
# Out:
# 3

# %% [markdown]
# Looking at the shape of the observation space

# %%
env = gym.make(game_name)
state_shape  = env.observation_space.shape
env.close()
state_shape
# Out:
# (2,)

# %% [markdown]
# ## Using Q-learning

# %%
env = gym.make(game_name) # 1. Load Environment and Q-table structure
Q = np.zeros([env.observation_space.n,env.action_space.n])
eta = .628
gma = .9
epis = 50000
rev_list = [] # rewards per episode calculate
for i in range(epis):
    s , _= env.reset()
    rAll = 0
    d = False
    j = 0
    while j < 99:
        j+=1
        a = np.argmax(Q[s,:] + np.random.randn(1,env.action_space.n)*(1./(i+1))) # 2. Choose an action by greedily (with noise) picking from Q table
        result = env.step(a) # collect new state & reward from environment
        s1 = result[0]
        r = result[1]
        d = result[2]
        Q[s,a] = Q[s,a] + eta*(r + gma*np.max(Q[s1,:]) - Q[s,a]) #Update Q-Table with new data
        rAll += r
        s = s1
        if d == True:
            break
    rev_list.append(rAll)
print("Reward Sum on all episodes " + str(sum(rev_list)/epis))
print("Final Values Q-Table")
print(Q)
# Out:
# Reward Sum on all episodes 7.27398
# Final Values Q-Table
# [[ 0.          0.          0.          0.          0.          0.        ]
#  [-4.4888983  -4.77215384 -4.67332178 -4.77215384  1.62261467 -6.28      ]
#  [-2.92267944 -3.22368354 -3.24928484 -3.22368354  7.7147     -6.28      ]
#  ...
#  [-2.76961539 -2.5877595  -2.76961539 -2.99686615 -6.28       -6.28      ]
#  [-3.64923622 -3.43770778 -3.64923622 -4.04696578 -6.28       -6.28      ]
#  [-1.2165616  -0.628      -0.628       8.87809126 -6.28       -6.28      ]]

# %% [markdown]
# In about 47 seconds, the model is trained to play Taxi-v3 game.
#
# ### testing the trained model

# %%
env = gym.make(game_name, render_mode='human') #<----- for rendering the environment with visualisation
s,_ = env.reset()
d = False
while d != True:
    a = np.argmax(Q[s,:] + np.random.randn(1,env.action_space.n)*(1./(i+1))) # Choose action from Q table
    # Collect new state & reward from environment
    result = env.step(a)
    s1 = result[0]
    r = result[1]
    d = result[2]
    Q[s,a] = Q[s,a] + eta*(r + gma*np.max(Q[s1,:]) - Q[s,a]) #Update Q-Table with new data
    s = s1
env.close()

# %% [markdown]
# ## Deep Q-learning

# %%
game_name = 'Taxi-v3'
env = gym.make(game_name)
discount_factor = 0.95
eps = 0.5
eps_decay_factor = 0.999
num_episodes=500

# %%
model = Sequential()
model.add(InputLayer(batch_input_shape=(1, env.observation_space.n)))
model.add(Dense(20, activation='relu'))
model.add(Dense(env.action_space.n, activation='linear'))
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %%
import time

for i in range(num_episodes):
    state = env.reset()
    eps *= eps_decay_factor
    j = 0
    done = False
    while j < 100:
        j+=1
        if np.random.random() < eps:
            action = np.random.randint(0, env.action_space.n)
        else:
            action = np.argmax(model.predict(np.identity(env.observation_space.n)[state:state + 1]))
        # env.render()
        result = env.step(action)
        new_state = result[0]
        reward = result[1]
        done = result[2]
        target = reward + discount_factor * np.max(model.predict(np.identity(env.observation_space.n)[new_state:new_state + 1]))
        target_vector = model.predict(np.identity(env.observation_space.n)[state:state + 1])[0]
        target_vector[action] = target
        model.fit(np.identity(env.observation_space.n)[state:state + 1], target_vector.reshape(-1, env.action_space.n), epochs=1, verbose=0)
        state = new_state
        if done:
            print("Training done in episode: {}/{}, score: {}, e: {:.2}".format(i, num_episodes, j, eps))
            model.save('taxi_model.h5')
            break
    if i % 100 == 0:
        print("Episode {} finished after {} timesteps".format(i, j))
    if done:
        break

env.close()
# Out:
# Episode 0 finished after 100 timesteps
# Training done in episode: 76/500, score: 29, e: 0.39

# %%
env = gym.make(game_name) #<----- for rendering the environment with visualisation
model.load_weights('taxi_model.h5')

s = env.reset()
d = False
while d != True:
    env.render(mode = "human")
    action = np.argmax(model.predict(np.identity(env.observation_space.n)[state:state + 1]))
    # Collect new state & reward from environment
    result = env.step(action)
    s1 = result[0]
    r = result[1]
    d = result[2]
    s = s1
    system('clear')
env.close()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)

# %% [markdown]
# ## Conclusion
#
# For this notebook exercise, I used Q-learning to train an AI to play the 'Taxi-v3' game that is available on the OpenAI gym. The code was simple to implement and most of the problems that occurred were caused by outdated documentation. <br>
#
# This exercise showed me that the Gym library an excellent tool is for learning reinforcement learning. This newly learned knowledge will be used for my open program project!
